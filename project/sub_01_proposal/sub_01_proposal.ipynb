# %% [markdown]
# # Submission 1 &ndash; Proposal
#
# ## Instructions
#
# - Fill out the *Team Information*, *Dataset Description* and *Hypotheses/Tasks* sections.
# - Make sure that this `.ipynb` file displays correctly in the GitHub file preview.
# - Push all required files before the deadline.

# %% [markdown]
# ---
# ## Team Information

# %% [markdown]
# **Team Name:** powerpuff-girls

# %% [markdown]
# **Team Members:**
# - Saba Zia Naserani
# - Elemdin Zukic
# - Egzona Gashi
# - TODO

# %% [markdown]
# ---
# ## Dataset Description
#
# Describe the dataset in your own words. What is it about? What are the attribtues? Why did you choose it? What makes it interesting? How big is? Where did you obtain it from?
# Use sentences or bullet points and no more than 250 words. Indicate the word count below.

# %% [markdown]
# **Description:** < This dataset contains metadata about movies and TV shows available on Netflix and is designed for analyzing trends in the streaming industry. It includes a variety of attributes such as title, type (movie or TV show), director, cast, country of production, release year, rating, duration, and genre classification.
#
# The dataset focuses on content characteristics and allows exploration of how media is produced and distributed across different regions and time periods. It enables the analysis of patterns such as the growth of Netflix content over the years, differences between movies and TV shows, and the diversity of genres available on the platform.
#
# Additionally, the dataset supports both simple and more complex analyses, such as comparing content types, identifying dominant genres, and examining how factors like country and release year influence the availability of titles.
#
# We chose this dataset because it is well structured, relatively large, and suitable for visualization tasks. It provides a good balance between simplicity and complexity.>

# %% [markdown]
# **Word count:** 143

# %% [markdown]
# ---
# ## Hypotheses/Tasks
#
# Describe what you plan to work on. You can either frame your plans as hypotheses about the dataset or as tasks that you wish to address with your visualizations. Be specific but concise. Each description should not be longer than two sentences. Indicate whether you framed your plans as hypotheses or tasks (use `**Hypothesis** / ~~Task~~` or `~~Hypothesis~~ / **Task**` in markdown).

# %% [markdown]
# ### A &ndash; Simple Hypotheses/Tasks

# %% [markdown]
# #### A.1
#
# **Hypothesis** / ~~Task~~
#
# < Movies seem to be more common on Netflix than TV shows, so the platform likely offers more movies than series overall. >

# %% [markdown]
# #### A.2
#
# **Hypothesis** / ~~Task~~
#
# < The number of titles on Netflix appears to have increased over time, which suggests that the platform has been expanding its content library. >

# %% [markdown]
# ### B &ndash; Complex Hypotheses/Tasks

# %% [markdown]
# ### B.1
#
# **Hypothesis** / ~~Task~~
#
# < Movies and TV shows differ in the genres they belong to, with certain genres being more dominant in one type of content, which may be influenced by differences in storytelling formats, audience expectations, and production strategies across the two content types. >

# %% [markdown]
# #### B.2
#
# **Hypothesis** / ~~Task~~
#
# < **Hypothesis**: The type of content available on Netflix depends on both the country and the release year, as cultural differences between regions and changes in global trends over time can influence what kind of content is produced, distributed, and made available on the platform. >
